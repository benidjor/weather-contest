# %% [markdown]
# # Fog Data

# %%
import requests
from xml.etree import ElementTree as ET

import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
from matplotlib import rcParams
import seaborn as sns
from scipy.stats import norm
from scipy.stats import shapiro
from scipy.stats import anderson
import statsmodels.api as sm
from datetime import datetime
from datetime import timedelta
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import chi2_contingency
from sklearn.model_selection import train_test_split
import os   

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## DATASET

# %%
raw_fog = pd.read_csv(f'C:/Users/USER/DATA WORK PLACE/2. DATA STUDY/6. WEATHER/data/fog_train.csv', encoding = 'euc-kr')
fog_test = pd.read_csv(f'C:/Users/USER/DATA WORK PLACE/2. DATA STUDY/6. WEATHER/data/fog_test.csv', encoding = 'euc-kr')

raw_fog
# Out:
#          Unnamed: 0 fog_train.year  fog_train.month  fog_train.day  \
# 0                 1              I                1              1
# 1                 2              I                1              1
# 2                 3              I                1              1
# 3                 4              I                1              1
# 4                 5              I                1              1
# ...             ...            ...              ...            ...
# 3156454     3156455              K               12             31
# 3156455     3156456              K               12             31
# 3156456     3156457              K               12             31
# 3156457     3156458              K               12             31
# 3156458     3156459              K               12             31
#
#          fog_train.time  fog_train.minute fog_train.stn_id  \
# 0                     0                10               AA
# 1                     0                20               AA
# 2                     0                30               AA
# 3                     0                40               AA
# 4                     0                50               AA
# ...                 ...               ...              ...
# 3156454              23                10               EC
# 3156455              23                20               EC
# 3156456              23                30               EC
# 3156457              23                40               EC
# 3156458              23                50               EC
#
#          fog_train.ws10_deg  fog_train.ws10_ms  fog_train.ta  fog_train.re  \
# 0                       0.0                0.0          -6.4           0.0
# 1                       0.0                0.0          -6.3           0.0
# 2                       0.0                0.0          -6.3           0.0
# 3                      27.8                0.4          -6.2           0.0
# 4                      59.7                0.5          -6.1           0.0
# ...                     ...                ...           ...           ...
# 3156454               305.3                7.7           2.5           0.0
# 3156455               293.8                5.7           2.3           0.0
# 3156456               274.2                4.9           2.2           0.0
# 3156457               270.3                4.6           2.1           0.0
# 3156458               254.8                4.1           2.1           0.0
#
#          fog_train.hm  fog_train.sun10  fog_train.ts  fog_train.vis1  \
# 0                38.9              0.0          -2.8           20000
# 1                37.9              0.0          -2.7           20000
# 2                40.0              0.0          -2.6           20000
# 3                39.5              0.0          -2.6           20000
# 4                39.8              0.0          -2.5           20000
# ...               ...              ...           ...             ...
# 3156454          50.2              0.0          -0.9           20000
# 3156455          50.1              0.0          -1.3           20000
# 3156456          51.0              0.0          -1.4           20000
# 3156457          51.7              0.0          -1.6           20000
# 3156458          53.3              0.0          -1.7           20000
#
#          fog_train.class
# 0                      4
# 1                      4
# 2                      4
# 3                      4
# 4                      4
# ...                  ...
# 3156454                4
# 3156455                4
# 3156456                4
# 3156457                4
# 3156458                4
#
# [3156459 rows x 16 columns]

# %%
fog_test
# Out:
#        fog_test.year  fog_test.month  fog_test.day  fog_test.time  \
# 0                  L               1             1              0
# 1                  L               1             1              0
# 2                  L               1             1              0
# 3                  L               1             1              0
# 4                  L               1             1              0
# ...              ...             ...           ...            ...
# 262795             L              12            31             23
# 262796             L              12            31             23
# 262797             L              12            31             23
# 262798             L              12            31             23
# 262799             L              12            31             23
#
#         fog_test.minute fog_test.stn_id  fog_test.ws10_deg  fog_test.ws10_ms  \
# 0                     0              AI              329.5               0.6
# 1                    10              AI              321.8               1.2
# 2                    20              AI                0.4               0.4
# 3                    30              AI              323.6               0.7
# 4                    40              AI              208.4               0.2
# ...                 ...             ...                ...               ...
# 262795               10              ED              338.8               6.1
# 262796               20              ED              335.2               5.8
# 262797               30              ED              337.1               5.3
# 262798               40              ED              322.0               3.7
# 262799               50              ED               33.6               2.8
#
#         fog_test.ta  fog_test.re  fog_test.hm  fog_test.sun10  fog_test.ts  \
# 0              -2.5          0.0         87.5             0.0         -1.6
# 1              -2.5          0.0         88.2             0.0         -1.6
# 2              -2.5          0.0         88.6             0.0         -1.7
# 3              -2.6          0.0         88.7             0.0         -1.6
# 4              -2.6          0.0         89.0             0.0         -1.6
# ...             ...          ...          ...             ...          ...
# 262795          4.5          0.0         71.3             0.0          1.9
# 262796          4.6          0.0         71.4             0.0          1.9
# 262797          4.5          0.0         72.1             0.0          1.8
# 262798          4.3          0.0         72.5             0.0          1.4
# 262799          4.3          0.0         73.7             0.0          1.3
#
#         fog_test.class
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 262795             NaN
# 262796             NaN
# 262797             NaN
# 262798             NaN
# 262799             NaN
#
# [262800 rows x 14 columns]

# %%
def raw_data_preprocessing_train(dataset):

    fog_data = dataset.copy()

    fog_data = fog_data.drop(['Unnamed: 0'], axis = 1)

    fog_data = fog_data.replace(-99.00, np.NaN)
    fog_data = fog_data.replace(-99.90, np.NaN)

    columns = fog_data.columns
    columns = [column.replace('fog_train.', "") for column in columns]
    fog_data.columns = columns

    return fog_data

def raw_data_preprocessing_test(dataset):

    fog_data = dataset.copy()

    fog_data = fog_data.replace(-99.00, np.NaN)
    fog_data = fog_data.replace(-99.90, np.NaN)

    columns = fog_data.columns
    columns = [column.replace('fog_test.', "") for column in columns]
    fog_data.columns = columns
    fog_data = fog_data.drop(['class'], axis = 1)

    return fog_data

# %%
fog_data = raw_data_preprocessing_train(raw_fog)

fog_data = fog_data.drop(['year', 'minute', 'day', 'vis1', 'ws10_deg'], axis = 1)

fog_test = raw_data_preprocessing_test(fog_test)

fog_test = fog_test.drop(['year', 'day', 'minute', 'ws10_deg'], axis = 1)

fog_data
# Out:
#          month  time stn_id  ws10_ms   ta   re    hm  sun10   ts  class
# 0            1     0     AA      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0     AA      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0     AA      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0     AA      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0     AA      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...    ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23     EC      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23     EC      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23     EC      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23     EC      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23     EC      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
# [3156459 rows x 10 columns]

# %%
fog_test
# Out:
#         month  time stn_id  ws10_ms   ta   re    hm  sun10   ts
# 0           1     0     AI      0.6 -2.5  0.0  87.5    0.0 -1.6
# 1           1     0     AI      1.2 -2.5  0.0  88.2    0.0 -1.6
# 2           1     0     AI      0.4 -2.5  0.0  88.6    0.0 -1.7
# 3           1     0     AI      0.7 -2.6  0.0  88.7    0.0 -1.6
# 4           1     0     AI      0.2 -2.6  0.0  89.0    0.0 -1.6
# ...       ...   ...    ...      ...  ...  ...   ...    ...  ...
# 262795     12    23     ED      6.1  4.5  0.0  71.3    0.0  1.9
# 262796     12    23     ED      5.8  4.6  0.0  71.4    0.0  1.9
# 262797     12    23     ED      5.3  4.5  0.0  72.1    0.0  1.8
# 262798     12    23     ED      3.7  4.3  0.0  72.5    0.0  1.4
# 262799     12    23     ED      2.8  4.3  0.0  73.7    0.0  1.3
#
# [262800 rows x 9 columns]

# %% [markdown]
# ### [전처리] 컬럼 추가

# %% [markdown]
# #### 결측치 제거(class 컬럼)

# %%
fog_data = fog_data.dropna(subset = ['class'])

# %% [markdown]
# #### 결측치 보간(기타 컬럼)

# %%
fog_data
# Out:
#          month  time stn_id  ws10_ms   ta   re    hm  sun10   ts  class
# 0            1     0     AA      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0     AA      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0     AA      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0     AA      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0     AA      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...    ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23     EC      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23     EC      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23     EC      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23     EC      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23     EC      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
# [3133943 rows x 10 columns]

# %%
fog_data = fog_data.dropna()
fog_test = fog_test.interpolate(method = 'quadratic', limit_direction = 'both')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9256\1227435585.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   fog_test = fog_test.interpolate(method = 'quadratic', limit_direction = 'both')

# %%
fog_data
# Out:
#          month  time stn_id  ws10_ms   ta   re    hm  sun10   ts  class
# 0            1     0     AA      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0     AA      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0     AA      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0     AA      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0     AA      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...    ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23     EC      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23     EC      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23     EC      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23     EC      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23     EC      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
# [2994869 rows x 10 columns]

# %% [markdown]
# #### 지역 컬럼 레이블링

# %%
def labelencoding_for_territory(dataset):

    stn_list = dataset['stn_id'].str[0]

    dataset['stn_id'] = stn_list

    stn_encoding_df = pd.DataFrame({
        'stn_id' : ['A', 'B', 'C', 'D', 'E'],
        'stn_num' : [1, 2, 3, 4, 5]
    })

    stn_encoding_map = stn_encoding_df.set_index('stn_id')['stn_num'].to_dict()
    # df를 series로 만든 후 dict형태로 변환하기
    dataset['stn_id'] = dataset['stn_id'].map(stn_encoding_map)
    return dataset

# %%
fog_data = labelencoding_for_territory(fog_data)
fog_test = labelencoding_for_territory(fog_test)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9256\3368638078.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['stn_id'] = stn_list
# C:\Users\USER\AppData\Local\Temp\ipykernel_9256\3368638078.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['stn_id'] = dataset['stn_id'].map(stn_encoding_map)

# %% [markdown]
# #### 이슬점 고려

# %%
fog_test
# Out:
#         month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts
# 0           1     0       1      0.6 -2.5  0.0  87.5    0.0 -1.6
# 1           1     0       1      1.2 -2.5  0.0  88.2    0.0 -1.6
# 2           1     0       1      0.4 -2.5  0.0  88.6    0.0 -1.7
# 3           1     0       1      0.7 -2.6  0.0  88.7    0.0 -1.6
# 4           1     0       1      0.2 -2.6  0.0  89.0    0.0 -1.6
# ...       ...   ...     ...      ...  ...  ...   ...    ...  ...
# 262795     12    23       5      6.1  4.5  0.0  71.3    0.0  1.9
# 262796     12    23       5      5.8  4.6  0.0  71.4    0.0  1.9
# 262797     12    23       5      5.3  4.5  0.0  72.1    0.0  1.8
# 262798     12    23       5      3.7  4.3  0.0  72.5    0.0  1.4
# 262799     12    23       5      2.8  4.3  0.0  73.7    0.0  1.3
#
# [262800 rows x 9 columns]

# %%
def dew_point(df):
    
    data = df.copy()

    a = 17.27
    b = 237.7
    
    T = data['ta']
    RH = data['hm']
    gamma = (a * T) / (b + T) + np.log(RH / 100.0)
    dew_point = (b * gamma) / (a - gamma)
    
    data['dew_point'] = dew_point
    
    return data

# %%
def dew_reach_column(df):
    
    data = df.copy()

    dew_re_list = []
    for i in range(len(data)):
        if data['ts'].values[i] < data['dew_point'].values[i]:
            dew_re_list.append(1)
        else:
            dew_re_list.append(0)
    data['dew_reached'] = dew_re_list
    
    data = data.drop(['dew_point'], axis = 1)
    
    return data

# %%
fog_data = dew_point(fog_data)
fog_test = dew_point(fog_test)

fog_data
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#          month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts  class  \
# 0            1     0       1      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0       1      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0       1      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0       1      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0       1      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...     ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23       5      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23       5      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23       5      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23       5      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23       5      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
#          dew_point
# 0       -18.083476
# 1       -18.299136
# 2       -17.664937
# 3       -17.722897
# 4       -17.543307
# ...            ...
# 3156454  -6.810493
# 3156455  -7.021146
# 3156456  -6.882689
# 3156457  -6.798347
# 3156458  -6.401821
#
# [2994869 rows x 11 columns]

# %%
fog_data = dew_reach_column(fog_data)
fog_test = dew_reach_column(fog_test)

fog_data
# Out:
#          month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts  class  \
# 0            1     0       1      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0       1      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0       1      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0       1      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0       1      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...     ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23       5      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23       5      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23       5      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23       5      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23       5      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
#          dew_reached
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3156454            0
# 3156455            0
# 3156456            0
# 3156457            0
# 3156458            0
#
# [2994869 rows x 11 columns]

# %%
fog_test
# Out:
#         month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts  dew_reached
# 0           1     0       1      0.6 -2.5  0.0  87.5    0.0 -1.6            0
# 1           1     0       1      1.2 -2.5  0.0  88.2    0.0 -1.6            0
# 2           1     0       1      0.4 -2.5  0.0  88.6    0.0 -1.7            0
# 3           1     0       1      0.7 -2.6  0.0  88.7    0.0 -1.6            0
# 4           1     0       1      0.2 -2.6  0.0  89.0    0.0 -1.6            0
# ...       ...   ...     ...      ...  ...  ...   ...    ...  ...          ...
# 262795     12    23       5      6.1  4.5  0.0  71.3    0.0  1.9            0
# 262796     12    23       5      5.8  4.6  0.0  71.4    0.0  1.9            0
# 262797     12    23       5      5.3  4.5  0.0  72.1    0.0  1.8            0
# 262798     12    23       5      3.7  4.3  0.0  72.5    0.0  1.4            0
# 262799     12    23       5      2.8  4.3  0.0  73.7    0.0  1.3            0
#
# [262800 rows x 10 columns]

# %% [markdown]
# #### 지상-지면온도차

# %%
fog_data['diff'] = fog_data['ta'] - fog_data['ts']
fog_test['diff'] = fog_test['ta'] - fog_test['ts']
fog_data
# Out:
#          month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts  class  \
# 0            1     0       1      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0       1      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0       1      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0       1      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0       1      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...     ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23       5      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23       5      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23       5      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23       5      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23       5      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
#          dew_reached  diff
# 0                  0  -3.6
# 1                  0  -3.6
# 2                  0  -3.7
# 3                  0  -3.6
# 4                  0  -3.6
# ...              ...   ...
# 3156454            0   3.4
# 3156455            0   3.6
# 3156456            0   3.6
# 3156457            0   3.7
# 3156458            0   3.8
#
# [2994869 rows x 12 columns]

# %% [markdown]
# ### [전처리] 스플릿

# %%
model_data = fog_data.copy()
test_data = fog_test.copy()
model_data
# Out:
#          month  time  stn_id  ws10_ms   ta   re    hm  sun10   ts  class  \
# 0            1     0       1      0.0 -6.4  0.0  38.9    0.0 -2.8    4.0
# 1            1     0       1      0.0 -6.3  0.0  37.9    0.0 -2.7    4.0
# 2            1     0       1      0.0 -6.3  0.0  40.0    0.0 -2.6    4.0
# 3            1     0       1      0.4 -6.2  0.0  39.5    0.0 -2.6    4.0
# 4            1     0       1      0.5 -6.1  0.0  39.8    0.0 -2.5    4.0
# ...        ...   ...     ...      ...  ...  ...   ...    ...  ...    ...
# 3156454     12    23       5      7.7  2.5  0.0  50.2    0.0 -0.9    4.0
# 3156455     12    23       5      5.7  2.3  0.0  50.1    0.0 -1.3    4.0
# 3156456     12    23       5      4.9  2.2  0.0  51.0    0.0 -1.4    4.0
# 3156457     12    23       5      4.6  2.1  0.0  51.7    0.0 -1.6    4.0
# 3156458     12    23       5      4.1  2.1  0.0  53.3    0.0 -1.7    4.0
#
#          dew_reached  diff
# 0                  0  -3.6
# 1                  0  -3.6
# 2                  0  -3.7
# 3                  0  -3.6
# 4                  0  -3.6
# ...              ...   ...
# 3156454            0   3.4
# 3156455            0   3.6
# 3156456            0   3.6
# 3156457            0   3.7
# 3156458            0   3.8
#
# [2994869 rows x 12 columns]

# %%
dataset_preprocessed = model_data.copy()
x_test = test_data.copy()

x = dataset_preprocessed.drop(['class'], axis = 1)
y = dataset_preprocessed['class']

x_train, x_valid, y_train, y_valid = train_test_split(x, y, train_size= 0.75, stratify = y, random_state=2077)
# stratify는 데이터 클래스의 비율을 일정한 수준으로 유지한채 데이터를 스플릿하는 함수임

# %%
x_train
# Out:
#          month  time  stn_id  ws10_ms    ta   re    hm  sun10    ts  \
# 2729857     11    11       2      2.3   9.3  0.0  72.5   0.15   9.8
# 352192       9    19       1      1.5  18.6  1.0  88.8   0.00  20.5
# 2734053     12    15       2      7.3 -11.7  0.0  22.3   0.21  -4.1
# 1505423      8    11       2      1.4  30.1  0.0  66.4   0.56  44.0
# 149669      11     9       1      6.0   8.6  0.0  32.0   0.25  10.1
# ...        ...   ...     ...      ...   ...  ...   ...    ...   ...
# 1794823      2     4       4      4.5  -4.8  0.0  47.6   0.00  -1.0
# 3155529     12    13       5      7.2   4.1  0.0  47.8   0.35   9.5
# 54386        1    16       1      3.0   2.4  0.0  44.8   0.05  -0.3
# 1930465      9     3       4      2.2  19.8  0.0  75.9   0.00  19.0
# 2387637      5    23       1      2.2  16.0  0.0  37.3   0.01  13.6
#
#          dew_reached  diff
# 2729857            0  -0.5
# 352192             0  -1.9
# 2734053            0  -7.6
# 1505423            0 -13.9
# 149669             0  -1.5
# ...              ...   ...
# 1794823            0  -3.8
# 3155529            0  -5.4
# 54386              0   2.7
# 1930465            0   0.8
# 2387637            0   2.4
#
# [2246151 rows x 11 columns]

# %%
y_train
# Out:
# 2729857    4.0
# 352192     4.0
# 2734053    4.0
# 1505423    4.0
# 149669     4.0
#           ...
# 1794823    4.0
# 3155529    4.0
# 54386      4.0
# 1930465    4.0
# 2387637    4.0
# Name: class, Length: 2246151, dtype: float64

# %% [markdown]
# ### [전처리] 행 삭제

# %% [markdown]
# #### 습도가 0인 데이터 삭제

# %%
def hm_0_drop(data):
    data = data[data['hm'] != 0]
    return data

# %%
x_train = hm_0_drop(x_train)
y_train = y_train[x_train.index]

# %% [markdown]
# #### 이상치 제거

# %%
def drop_outlier_std(data, column, num):
    mean_value = data[column].mean()
    std_value = data[column].std()
    data = data[np.abs(data[column] - mean_value) <= num * std_value]
    return data

# %%
def drop_outlier_iqr(data, column, ptg):

    ptg_other_side = 1 - ptg

    Q1 = data[column].quantile(ptg)  # 1사분위수 (Q1)
    Q3 = data[column].quantile(ptg_other_side)  # 3사분위수 (Q3)
    IQR = Q3 - Q1                   # IQR (Q3 - Q1)
    
    lower_bound = Q1 - 1.5 * IQR    # 하한선
    upper_bound = Q3 + 1.5 * IQR    # 상한선
    
    # 이상치를 제거하고 데이터프레임 반환
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
x_train = drop_outlier_iqr(x_train, 'diff', 0.25)
x_train = drop_outlier_iqr(x_train, 'ta', 0.25)
x_train = drop_outlier_iqr(x_train, 'ts', 0.25)
x_train = drop_outlier_iqr(x_train, 'hm', 0.25)
x_train = drop_outlier_iqr(x_train, 'ws10_ms', 0.25)

y_train = y_train[x_train.index]

# %% [markdown]
# ### [전처리] 범주화

# %%
def categorizing(data, column, n_quantile):
    data[column] = data[column].astype(float)
    min_value = data[column].min()
    max_value = data[column].max()
    bins = np.linspace(min_value, max_value, n_quantile + 1)
    labels = [i for i in range(1, n_quantile + 1)]
    data[column] = pd.cut(data[column], bins = bins, labels = labels, include_lowest=True)
    return data

# %%
categorization_list = ['ws10_ms', 'ta', 'hm', 'sun10', 'ts', 'diff']

for column in categorization_list:
    x_train = categorizing(x_train, column, 30)

for column in categorization_list:
    x_valid = categorizing(x_valid, column, 30)

for column in categorization_list:
    x_test = categorizing(x_test, column, 30)

# %%
x_train
# Out:
#          month  time  stn_id ws10_ms  ta   re  hm sun10  ts  dew_reached diff
# 2729857     11    11       2      11  14  0.0  22     1   9            0   17
# 352192       9    19       1       8  20  1.0  27     1  15            0   14
# 149669      11     9       1      29  14  0.0   9     1   9            0   15
# 2964761      5    18       4      14  20  0.0  15     1  17            0   12
# 68712        4     4       1       7  13  0.0  18     1   7            0   18
# ...        ...   ...     ...     ...  ..  ...  ..   ...  ..          ...  ...
# 229487       5    16       1      14  18  0.0  29     1  14            0   14
# 1794823      2     4       4      22   6  0.0  14     1   3            0   11
# 54386        1    16       1      15  10  0.0  13     1   3            0   22
# 1930465      9     3       4      11  20  0.0  23     1  14            0   19
# 2387637      5    23       1      11  18  0.0  10     1  11            0   22
#
# [2006944 rows x 11 columns]

# %% [markdown]
# # CLASSIFICATION

# %%
import tensorflow as tf

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer
from sklearn.inspection import permutation_importance

# %% [markdown]
# ### DATA class check

# %%
def class_info(dataset, msg = ""):
    try:

        unique_values, counts = np.unique(dataset['class'], return_counts = True)
        
        print("[ " + msg + "의 class별 count / ratio ]")
        print("-"*40)
        for value, count in zip(unique_values, counts):
            print('class ' + f'{int(value)}: {count}' + " / " + str(round(count/len(dataset['class'])*100, 2)) + "%")
        
        print("-"*40)
        fog_count = len(dataset[dataset['class'] < 4]['class'])
        print("안개 : " + str(fog_count) + " / " + str(round(fog_count/len(dataset['class'])*100, 2)) + "%")

    except:

        unique_values, counts = np.unique(dataset, return_counts = True)
        
        print("[ " + msg + "의 class별 count / ratio ]")
        print("-"*40)
        for value, count in zip(unique_values, counts):
            print('class ' + f'{int(value)}: {count}' + " / " + str(round(count/len(dataset)*100, 2)) + "%")
        
        print("-"*40)
        fog_count = len(dataset[dataset < 4])
        print("안개 : " + str(fog_count) + " / " + str(round(fog_count/len(dataset)*100, 2)) + "%")

# %%
class_info(model_data, "전체 trainset")
# Out:
# [ 전체 trainset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 7806 / 0.26%
# class 2: 11975 / 0.4%
# class 3: 11940 / 0.4%
# class 4: 2963148 / 98.94%
# ----------------------------------------
# 안개 : 31721 / 1.06%

# %%
class_info(y_train, "splited trainset")
# Out:
# [ splited trainset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 5797 / 0.29%
# class 2: 8840 / 0.44%
# class 3: 8732 / 0.44%
# class 4: 1983575 / 98.84%
# ----------------------------------------
# 안개 : 23369 / 1.16%

# %%
class_info(y_valid, "splited validset")
# Out:
# [ splited validset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 1951 / 0.26%
# class 2: 2994 / 0.4%
# class 3: 2985 / 0.4%
# class 4: 740788 / 98.94%
# ----------------------------------------
# 안개 : 7930 / 1.06%

# %% [markdown]
# ## models

# %% [markdown]
# - GridSearch의 목표 score 함수 설정

# %%
def grid_csi_index(y_true, y_pred):
    
    model_cm = confusion_matrix(y_true, y_pred, labels = [1, 2, 3, 4])

    H = (model_cm[0][0] + model_cm[1][1] + model_cm[2][2])
    F = (model_cm[0][1] + model_cm[0][2] + 
         model_cm[1][0] + model_cm[1][2] + 
         model_cm[2][0] + model_cm[2][1] +
         model_cm[3][0] + model_cm[3][1] + model_cm[3][2])
    M = (model_cm[0][3] + model_cm[1][3] + model_cm[2][3])

    model_csi = H / (H + F + M)

    return model_csi

custom_scorer = make_scorer(grid_csi_index)

# %% [markdown]
# ### KNN

# %% [markdown]
# #### [KNN] modeling

# %%
def KNN_modeling(X_train, Y_train, X_valid, Y_valid, X_test):

    x_train = X_train.copy()
    y_train = Y_train.copy()
    x_valid = X_valid.copy()
    y_valid = Y_valid.copy()
    x_test = X_test.copy()

    param_grid = {'n_neighbors': [3, 5], 
                  'weights': ['uniform', 'distance'], 
                  'metric': ['euclidean', 'manhattan']}
    
    knn = KNeighborsClassifier()
    knn_model_grid = GridSearchCV(knn, 
                                param_grid, 
                                n_jobs = -1, 
                                cv = 3, 
                                scoring = custom_scorer)

    with tf.device('/GPU:0'):
        knn_model = knn_model_grid.fit(x_train, y_train)

    knn_best_model = knn_model.best_estimator_
    knn_valid_pred = knn_best_model.predict(x_valid)
    knn_cm = confusion_matrix(y_valid, knn_valid_pred, labels = [1, 2, 3, 4])

    cm = knn_cm

    H = (cm[0][0] + cm[1][1] + cm[2][2])
    F = (cm[0][1] + cm[0][2] + 
         cm[1][0] + cm[1][2] + 
         cm[2][0] + cm[2][1] +
         cm[3][0] + cm[3][1] + cm[3][2])
    M = (cm[0][3] + cm[1][3] + cm[2][3])

    knn_csi = H / (H + F + M)
    
    knn_test_pred = knn_best_model.predict(x_test)

    return knn_best_model, knn_cm, knn_csi, knn_test_pred

# %%
knn_best_model, knn_cm, knn_csi, knn_test_pred = KNN_modeling(x_train, y_train, x_valid, y_valid, x_test)
with open('knn_best_model(categorization).pkl', 'wb') as file:
  pickle.dump(knn_best_model, file)

# %%
knn_csi
# Out:
# 0.03136025088200706

# %%
plt.figure(figsize=(10,5))

unique_value_list = []
unique_value = [1, 2, 3, 4]
for i, value in enumerate(unique_value):
    unique_value_list.append("class " + str(int(value)))

pred_labels = unique_value_list
sns.heatmap(knn_cm, 
            annot=True, 
            fmt="d", 
            cmap="Blues", 
            xticklabels = pred_labels, 
            yticklabels = pred_labels)
plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
class_info(y_train, "test dataset")
# Out:
# [ test dataset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 5797 / 0.29%
# class 2: 8840 / 0.44%
# class 3: 8732 / 0.44%
# class 4: 1983575 / 98.84%
# ----------------------------------------
# 안개 : 23369 / 1.16%

# %%
class_info(y_valid, "test dataset")
# Out:
# [ test dataset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 1951 / 0.26%
# class 2: 2994 / 0.4%
# class 3: 2985 / 0.4%
# class 4: 740788 / 98.94%
# ----------------------------------------
# 안개 : 7930 / 1.06%

# %%
class_info(knn_test_pred, "test dataset")
# Out:
# [ test dataset의 class별 count / ratio ]
# ----------------------------------------
# class 1: 2245 / 0.85%
# class 2: 1628 / 0.62%
# class 3: 272 / 0.1%
# class 4: 258655 / 98.42%
# ----------------------------------------
# 안개 : 4145 / 1.58%

# %%
pd.DataFrame(knn_test_pred).to_csv('knn_test_pred(categorization).csv')
